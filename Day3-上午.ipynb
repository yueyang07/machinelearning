# %% [markdown]
# ## RNN 文本分类任务实战
#
# - 数据集构建：影评数据集进行情感分析（分类任务）
# - 词向量模型：加载训练好的词向量或者自己训练都可以
# - 序列网络模型：训练RNN模型进行识别

# %% [markdown]
# ![title](./img/24.png)

# %% [markdown]
# ### RNN模型所需数据解读：
#
# ![title](./img/31.png)

# %% [markdown]
# ### 隐藏层计算方式
# - g 代表激活函数
# - h (t-1) 代表上一个时刻的隐藏层神经元计算结果
# - x (t) 代表当前时刻的输入参数
# - w 均表示一个需要被学习的参数
# ![title](./img/34.PNG)

# %% [markdown]
# ### 压缩文件

# %%
! unzip ./data.zip -d ./
# Out:
# Archive:  ./data.zip
#    creating: ./data/
#   inflating: ./data/train.txt
#   inflating: ./data/xiaohuangji50w_nofenci.conv
#   inflating: ./data/test.txt

# %%
import os
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
import numpy as np

import pprint
import logging
import time

# python 内置用作统计的模块
from collections import Counter

# python 内置构建路径的方法
from pathlib import Path

# 获取进度的方法
from tqdm import tqdm

# %%
import tensorflow

# %% [markdown]
# ### 加载影评数据集

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data()

# %%
x_train.shape
# Out:
# (25000,)

# %% [markdown]
# ### 查看数据

# %%
x_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
#  107,
#  117,
#  5952,
#  15,
#  256,
#  4,
#  31050,
#  7,
#  3766,
#  5,
#  723,
#  36,
#  71,
#  43,
#  530,
#  476,
#  26,
#  400,
#  317,
#  46,
#  7,
#  4,
#  12118,
#  1029,
#  13,
#  104,
#  88,
#  4,
#  381,
#  15,
#  297,
#  98,
#  32,
#  2071,
#  56,
#  26,
#  141,
#  6,
#  194,
#  7486,
#  18,
#  4,
#  226,
#  22,
#  21,
#  134,
#  476,
#  26,
#  480,
#  5,
#  144,
#  30,
#  5535,
#  18,
#  51,
#  36,
#  28,
#  224,
#  92,
#  25,
#  104,
#  4,
#  226,
#  65,
#  16,
#  38,
#  1334,
#  88,
#  12,
#  16,
#  283,
#  5,
#  16,
#  4472,
#  113,
#  103,
#  32,
#  15,
#  16,
#  5345,
#  19,
#  178,
#  32]

# %% [markdown]
# ### 建立词和ID的映射表，增加3个特殊字符
# - word2idx['pad'] = 0 表示填充字符
# - word2idx['start'] = 1 表示开始字符
# - word2idx['unk'] = 2 表示不在词表范围内的数据

# %%
# 获取电影评论 word 到 index的关系对应表
_word2idx = tf.keras.datasets.imdb.get_word_index()

# 将所有索引往后加三
word2idx = {w: i+3 for w, i in _word2idx.items()}

# 填充三个特定的字符
word2idx['<pad>'] = 0
word2idx['<start>'] = 1
word2idx['<unk>'] = 2

# 获取index 对word是词
idx2word = {i: w for w, i in word2idx.items()}

# %% [markdown]
# ### 按文本长度大小进行排序

# %%
def sort_by_len(x, y):
    x, y = np.asarray(x), np.asarray(y)
    idx = sorted(range(len(x)), key=lambda i: len(x[i]))
    return x[idx], y[idx]

# %% [markdown]
# ### 将文本数据结果保存到本地

# %%
x_train, y_train = sort_by_len(x_train, y_train)
x_test, y_test = sort_by_len(x_test, y_test)

def write_file(f_path, xs, ys):
    with open(f_path, 'w',encoding='utf-8') as f:
        for x, y in zip(xs, ys):
            f.write(str(y)+'\t'+' '.join([idx2word[i] for i in x][1:])+'\n')

# 写入本地文件
write_file('./data/train.txt', x_train, y_train)
write_file('./data/test.txt', x_test, y_test)

# %% [markdown]
# ### 构建语料表，基于词频来进行统计

# %%
counter = Counter()

with open('./data/train.txt',encoding='utf-8') as f:
    for line in f:
        line = line.rstrip()
        label, words = line.split('\t')
        words = words.split(' ')
        
        # 自动对word 进行计数
        counter.update(words)

# 构建二级词表，这个词表是用来获取 出现次数大于等于10的所有单词 加上一个额外用来填充的字符
words = ['<pad>'] + [w for w, freq in counter.most_common() if freq >= 10]

print('Vocab Size:', len(words))

# 制作词表目录
Path('./vocab').mkdir(exist_ok=True)

with open('./vocab/word.txt', 'w',encoding='utf-8') as f:
    for w in words:
        f.write(w+'\n')
# Out:
# Vocab Size: 20598

# %% [markdown]
# ### 得到新的词表

# %%
word2idx = {}

# 保存到词表的新词库
with open('./vocab/word.txt',encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i

# %% [markdown]
# ### embedding层
# - 可以基于网络来训练，也可以直接加载别人训练好的，一般都是加载预训练模型
# - 这里有一些常用的：https://nlp.stanford.edu/projects/glove/

# %% [markdown]
# ![title](./img/25.png)

# %% [markdown]
# ### 构建词嵌入矩阵（迁移学习）【20599*50】

# %%
# 构建初始矩阵
embedding = np.zeros((len(word2idx)+1, 50)) # + 1 表示如果不在语料表中，就都是unknow

with open('./rnn_data/glove.6B.50d.txt',encoding='utf-8') as f: #下载好的词向量矩阵数据
    count = 0
    for i, line in enumerate(f):
        if i % 100000 == 0:
            print('- line {}'.format(i)) #打印处理了多少数据
        
        # 删除前后的空格
        line = line.rstrip()
        
        sp = line.split(' ')
        
        #默认下载的向量矩阵是第一个是单词， 其余的是向量
        word, vec = sp[0], sp[1:]
        if word in word2idx:
            count += 1
            
            #将词转换成对应的向量
            embedding[word2idx[word]] = np.asarray(vec, dtype='float32')
# Out:
# - line 0
# - line 100000
# - line 200000
# - line 300000

# %% [markdown]
# ### 存储词向量文件

# %%
print("[%d / %d] words have found pre-trained values"%(count, len(word2idx)))
np.save('./vocab/word.npy', embedding)
print('Saved ./vocab/word.npy')
# Out:
# [19676 / 20598] words have found pre-trained values
# Saved ./vocab/word.npy

# %% [markdown]
# ### 构建训练数据
#
# - 注意所有的输入样本必须都是相同shape（文本长度，词向量维度等）
#
# - tf.data.Dataset.from_tensor_slices(tensor)：将tensor沿其第一个维度切片，返回一个含有N个样本的数据集，这样做的问题就是需要将整个数据集整体传入，然后切片建立数据集类对象，比较占内存。
#
# - tf.data.Dataset.from_generator(data_generator,output_data_type,output_data_shape)：从一个生成器中不断读取样本

# %%
def data_generator(f_path, params):
    with open(f_path,encoding='utf-8') as f:
        print('Reading', f_path)
        for line in f:
            line = line.rstrip()
            label, text = line.split('\t')
            text = text.split(' ')
            
            # 得到当前词所对应的ID
            x = [params['word2idx'].get(w, len(word2idx)) for w in text] 
            
            # 截断操作
            if len(x) >= params['max_len']: 
                x = x[:params['max_len']]
            else:
                # 补齐操作
                x += [0] * (params['max_len'] - len(x)) 
            y = int(label)
            yield x, y

# %% [markdown]
# ### 自定义构建dataset

# %%
def dataset(is_training, params):
    _shapes = ([params['max_len']], ())
    _types = (tf.int32, tf.int32)
  
    if is_training:
        
        # 非常实用
        ds = tf.data.Dataset.from_generator(
            lambda: data_generator(params['train_path'], params),
            output_shapes = _shapes,
            output_types = _types,)
        
        
        # 对数据进行打乱
        ds = ds.shuffle(params['num_samples'])
        
        # 对数据批处理化
        ds = ds.batch(params['batch_size'])
        
        #设置缓存序列，根据可用的CPU动态设置并行调用的数量，为了怎加训练速度
        ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    else:
        ds = tf.data.Dataset.from_generator(
            lambda: data_generator(params['test_path'], params),
            output_shapes = _shapes,
            output_types = _types,)
        ds = ds.batch(params['batch_size'])
        
        # 高性能预获取数据的方法
        ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
  
    return ds

# %% [markdown]
# ### 自定义网络模型
# - 定义好都有哪些层
# - 前向传播走一遍就行了

# %% [markdown]
# embedding_lookup的作用：

# %% [markdown]
# ![title](./img/26.png)

# %% [markdown]
# ![title](./img/32.png)

# %% [markdown]
# ### LSTM 模型概要
# <img src="./img/35.PNG" alt="FAO" width="700">
# <img src="./img/36.PNG" alt="FAO" width="300">
# <img src="./img/37.PNG" alt="FAO" width="300">
# <img src="./img/38.PNG" alt="FAO" width="300">
# <img src="./img/39.PNG" alt="FAO" width="300">
# <img src="./img/40.PNG" alt="FAO" width="300">
# <img src="./img/41.PNG" alt="FAO" width="300">

# %%
class Model(tf.keras.Model):
    def __init__(self, params):
        super().__init__()
    
        # 嵌入层
        self.embedding = tf.Variable(np.load('./vocab/word.npy'),
                                     dtype=tf.float32,
                                     name='pretrained_embedding',
                                     trainable=False,)

        # dropout 层
        self.drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop3 = tf.keras.layers.Dropout(params['dropout_rate'])

        # LSTM 层 return_sequences 是否返回序列 Bidirectional 参数X2 return_sequences 返回序列
        self.rnn1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        
        # 返回全局信息
        self.rnn3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=False))

        self.drop_fc = tf.keras.layers.Dropout(params['dropout_rate'])
        
        # 全连接结果
        self.fc = tf.keras.layers.Dense(2*params['rnn_units'], tf.nn.relu)

        # 输出二分类
        self.out_linear = tf.keras.layers.Dense(2)

  
    def call(self, inputs, training=False):
        if inputs.dtype != tf.int32:
            inputs = tf.cast(inputs, tf.int32)
    
        batch_sz = tf.shape(inputs)[0]
        rnn_units = 2*params['rnn_units']

        # 嵌入层引用
        x = tf.nn.embedding_lookup(self.embedding, inputs)
        
        # 训练时候dropout使用，预测时候没有dropout
        x = self.drop1(x, training=training)
        x = self.rnn1(x)

        x = self.drop2(x, training=training)
        x = self.rnn2(x)

        x = self.drop3(x, training=training)
        x = self.rnn3(x)

        x = self.drop_fc(x, training=training)
        x = self.fc(x)

        x = self.out_linear(x)

        return x

# %% [markdown]
# ### 速度会更快

# %%
class Model(tf.keras.Model):
    def __init__(self, params):
        super().__init__()
    
        self.embedding = tf.Variable(np.load('./vocab/word.npy'),
                                     dtype=tf.float32,
                                     name='pretrained_embedding',
                                     trainable=False,)

        self.drop1 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop2 = tf.keras.layers.Dropout(params['dropout_rate'])
        self.drop3 = tf.keras.layers.Dropout(params['dropout_rate'])

        self.rnn1 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        self.rnn2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))
        
        # 与第一个模型的区别
        self.rnn3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(params['rnn_units'], return_sequences=True))

        self.drop_fc = tf.keras.layers.Dropout(params['dropout_rate'])
        self.fc = tf.keras.layers.Dense(2*params['rnn_units'], tf.nn.elu)

        self.out_linear = tf.keras.layers.Dense(2)

  
    def call(self, inputs, training=False):
        if inputs.dtype != tf.int32:
            inputs = tf.cast(inputs, tf.int32)
    
        batch_sz = tf.shape(inputs)[0]
        rnn_units = 2*params['rnn_units']

        x = tf.nn.embedding_lookup(self.embedding, inputs)
        
        # 维度转换
        # 最大长度参数为1000 * 1 转换为 10*10 * 10 
        x = tf.reshape(x, (batch_sz*10*10, 10, 50))
        
        x = self.drop1(x, training=training)
        x = self.rnn1(x)
        
        # 压缩成 1/10
        x = tf.reduce_max(x, 1)

        x = tf.reshape(x, (batch_sz*10, 10, rnn_units))
        
        x = self.drop2(x, training=training)
        x = self.rnn2(x)
        x = tf.reduce_max(x, 1)

        x = tf.reshape(x, (batch_sz, 10, rnn_units))
        x = self.drop3(x, training=training)
        
        x = self.rnn3(x)
        x = tf.reduce_max(x, 1)

        x = self.drop_fc(x, training=training)
        x = self.fc(x)

        x = self.out_linear(x)

        return x

# %% [markdown]
# ### 设置参数

# %%
params = {
  'vocab_path': './vocab/word.txt',
  'train_path': './data/train.txt',
  'test_path': './data/test.txt',
  'num_samples': 25000,
  'num_labels': 2,
  'batch_size': 32,
  'max_len': 1000,
  'rnn_units': 200, # rnn特征数量
  'dropout_rate': 0.2,
  'clip_norm': 10., # 梯度截断，为了防止过拟合，在RNN中尤其明显
  'num_patience': 3, # early stoping，三次为提升就直接停止训练
  'lr': 3e-4,
}

# %% [markdown]
# ### 用来判断进行提前停止
# - early stoping

# %%
def is_descending(history: list):
    history = history[-(params['num_patience']+1):]
    for i in range(1, len(history)):
        if history[i-1] <= history[i]:
            return False
    return True

# %% [markdown]
# ### 读取语料数据表

# %%
word2idx = {}
with open(params['vocab_path'],encoding='utf-8') as f:
    for i, line in enumerate(f):
        line = line.rstrip()
        word2idx[line] = i
params['word2idx'] = word2idx
params['vocab_size'] = len(word2idx) + 1

# %% [markdown]
# ### 构建模型

# %%
model = Model(params)
model.build(input_shape=(None, None))#设置输入的大小，或者fit时候也能自动找到

# %% [markdown]
# ### 学习率自动下降
# - 链接：https://tensorflow.google.cn/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay?version=stable
# - return initial_learning_rate * decay_rate ^ (step / decay_steps)

# %%
decay_lr = tf.optimizers.schedules.ExponentialDecay(params['lr'], 1000, 0.95)#相当于加了一个指数衰减函数
optim = tf.optimizers.Adam(params['lr'])
global_step = 0

history_acc = []
best_acc = .0

t0 = time.time()
logger = logging.getLogger('tensorflow')
logger.setLevel(logging.INFO)

# %% [markdown]
# ## 自定义训练模型

# %%
while True:
    # 训练模型
    for texts, labels in dataset(is_training=True, params=params):
        
        #梯度带，记录所有在上下文中的操作，并且通过调用.gradient()获得任何上下文中计算得出的张量的梯度
        with tf.GradientTape() as tape:
            logits = model(texts, training=True)
            loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=labels, logits=logits)
            loss = tf.reduce_mean(loss)
  
        optim.lr.assign(decay_lr(global_step))
        grads = tape.gradient(loss, model.trainable_variables)
        
        #将梯度限制一下，有的时候回更新太猛，防止过拟合
        grads, _ = tf.clip_by_global_norm(grads, params['clip_norm']) 
        
        #更新梯度
        optim.apply_gradients(zip(grads, model.trainable_variables))

        if global_step % 50 == 0:
            logger.info("Step {} | Loss: {:.4f} | Spent: {:.1f} secs | LR: {:.6f}".format(
                global_step, loss.numpy().item(), time.time()-t0, optim.lr.numpy().item()))
            t0 = time.time()
        global_step += 1

    # 验证集效果
    m = tf.keras.metrics.Accuracy()

    for texts, labels in dataset(is_training=False, params=params):
        logits = model(texts, training=False)
        y_pred = tf.argmax(logits, axis=-1)
        m.update_state(y_true=labels, y_pred=y_pred)
    
    acc = m.result().numpy()
    logger.info("Evaluation: Testing Accuracy: {:.3f}".format(acc))
    history_acc.append(acc)
  
    if acc > best_acc:
        best_acc = acc
    logger.info("Best Accuracy: {:.3f}".format(best_acc))
  
    # eaaly stoping 提前停止训练
    if len(history_acc) > params['num_patience'] and is_descending(history_acc):
        logger.info("Testing Accuracy not improved over {} epochs, Early Stop".format(params['num_patience']))
        break
# Out:
# Reading ./data/train.txt
# INFO:tensorflow:Step 0 | Loss: 0.6993 | Spent: 36.8 secs | LR: 0.000300
# INFO:tensorflow:Step 50 | Loss: 0.6779 | Spent: 2.8 secs | LR: 0.000299
# INFO:tensorflow:Step 100 | Loss: 0.5533 | Spent: 2.8 secs | LR: 0.000298
# INFO:tensorflow:Step 150 | Loss: 0.6616 | Spent: 2.7 secs | LR: 0.000298
# INFO:tensorflow:Step 200 | Loss: 0.4537 | Spent: 2.8 secs | LR: 0.000297
# INFO:tensorflow:Step 250 | Loss: 0.5894 | Spent: 2.7 secs | LR: 0.000296
# INFO:tensorflow:Step 300 | Loss: 0.4209 | Spent: 2.8 secs | LR: 0.000295
# INFO:tensorflow:Step 350 | Loss: 0.5410 | Spent: 2.8 secs | LR: 0.000295
# INFO:tensorflow:Step 400 | Loss: 0.4823 | Spent: 2.8 secs | LR: 0.000294
# INFO:tensorflow:Step 450 | Loss: 0.4093 | Spent: 2.7 secs | LR: 0.000293
# INFO:tensorflow:Step 500 | Loss: 0.5211 | Spent: 2.7 secs | LR: 0.000292
# INFO:tensorflow:Step 550 | Loss: 0.5745 | Spent: 2.7 secs | LR: 0.000292
# INFO:tensorflow:Step 600 | Loss: 0.3983 | Spent: 2.8 secs | LR: 0.000291
# INFO:tensorflow:Step 650 | Loss: 0.3779 | Spent: 2.8 secs | LR: 0.000290
# INFO:tensorflow:Step 700 | Loss: 0.3805 | Spent: 2.7 secs | LR: 0.000289
# INFO:tensorflow:Step 750 | Loss: 0.3554 | Spent: 2.8 secs | LR: 0.000289
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.808
# INFO:tensorflow:Best Accuracy: 0.808
# Reading ./data/train.txt
# INFO:tensorflow:Step 800 | Loss: 0.3931 | Spent: 31.1 secs | LR: 0.000288
# INFO:tensorflow:Step 850 | Loss: 0.3510 | Spent: 2.8 secs | LR: 0.000287
# INFO:tensorflow:Step 900 | Loss: 0.3978 | Spent: 2.7 secs | LR: 0.000286
# INFO:tensorflow:Step 950 | Loss: 0.4339 | Spent: 2.7 secs | LR: 0.000286
# INFO:tensorflow:Step 1000 | Loss: 0.5159 | Spent: 2.8 secs | LR: 0.000285
# INFO:tensorflow:Step 1050 | Loss: 0.2017 | Spent: 2.8 secs | LR: 0.000284
# INFO:tensorflow:Step 1100 | Loss: 0.2915 | Spent: 2.8 secs | LR: 0.000284
# INFO:tensorflow:Step 1150 | Loss: 0.5173 | Spent: 2.8 secs | LR: 0.000283
# INFO:tensorflow:Step 1200 | Loss: 0.3093 | Spent: 2.8 secs | LR: 0.000282
# INFO:tensorflow:Step 1250 | Loss: 0.3496 | Spent: 2.8 secs | LR: 0.000281
# INFO:tensorflow:Step 1300 | Loss: 0.5393 | Spent: 2.8 secs | LR: 0.000281
# INFO:tensorflow:Step 1350 | Loss: 0.4146 | Spent: 2.8 secs | LR: 0.000280
# INFO:tensorflow:Step 1400 | Loss: 0.2133 | Spent: 2.8 secs | LR: 0.000279
# INFO:tensorflow:Step 1450 | Loss: 0.4556 | Spent: 2.8 secs | LR: 0.000278
# INFO:tensorflow:Step 1500 | Loss: 0.2556 | Spent: 2.8 secs | LR: 0.000278
# INFO:tensorflow:Step 1550 | Loss: 0.3512 | Spent: 2.8 secs | LR: 0.000277
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.838
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ./data/train.txt
# INFO:tensorflow:Step 1600 | Loss: 0.5215 | Spent: 31.0 secs | LR: 0.000276
# INFO:tensorflow:Step 1650 | Loss: 0.3604 | Spent: 2.8 secs | LR: 0.000276
# INFO:tensorflow:Step 1700 | Loss: 0.4307 | Spent: 2.8 secs | LR: 0.000275
# INFO:tensorflow:Step 1750 | Loss: 0.2863 | Spent: 2.8 secs | LR: 0.000274
# INFO:tensorflow:Step 1800 | Loss: 0.4197 | Spent: 2.8 secs | LR: 0.000274
# INFO:tensorflow:Step 1850 | Loss: 0.3884 | Spent: 2.8 secs | LR: 0.000273
# INFO:tensorflow:Step 1900 | Loss: 0.4118 | Spent: 2.8 secs | LR: 0.000272
# INFO:tensorflow:Step 1950 | Loss: 0.3332 | Spent: 2.8 secs | LR: 0.000271
# INFO:tensorflow:Step 2000 | Loss: 0.4061 | Spent: 2.8 secs | LR: 0.000271
# INFO:tensorflow:Step 2050 | Loss: 0.3596 | Spent: 2.8 secs | LR: 0.000270
# INFO:tensorflow:Step 2100 | Loss: 0.5128 | Spent: 2.8 secs | LR: 0.000269
# INFO:tensorflow:Step 2150 | Loss: 0.2109 | Spent: 2.8 secs | LR: 0.000269
# INFO:tensorflow:Step 2200 | Loss: 0.4685 | Spent: 2.8 secs | LR: 0.000268
# INFO:tensorflow:Step 2250 | Loss: 0.2463 | Spent: 2.8 secs | LR: 0.000267
# INFO:tensorflow:Step 2300 | Loss: 0.2890 | Spent: 2.8 secs | LR: 0.000267
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.837
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ./data/train.txt
# INFO:tensorflow:Step 2350 | Loss: 0.3964 | Spent: 31.2 secs | LR: 0.000266
# INFO:tensorflow:Step 2400 | Loss: 0.2773 | Spent: 2.7 secs | LR: 0.000265
# INFO:tensorflow:Step 2450 | Loss: 0.4066 | Spent: 2.8 secs | LR: 0.000265
# INFO:tensorflow:Step 2500 | Loss: 0.3484 | Spent: 2.8 secs | LR: 0.000264
# INFO:tensorflow:Step 2550 | Loss: 0.3842 | Spent: 2.8 secs | LR: 0.000263
# INFO:tensorflow:Step 2600 | Loss: 0.4319 | Spent: 2.8 secs | LR: 0.000263
# INFO:tensorflow:Step 2650 | Loss: 0.3681 | Spent: 2.8 secs | LR: 0.000262
# INFO:tensorflow:Step 2700 | Loss: 0.2082 | Spent: 2.7 secs | LR: 0.000261
# INFO:tensorflow:Step 2750 | Loss: 0.2327 | Spent: 2.8 secs | LR: 0.000261
# INFO:tensorflow:Step 2800 | Loss: 0.3265 | Spent: 2.8 secs | LR: 0.000260
# INFO:tensorflow:Step 2850 | Loss: 0.3556 | Spent: 2.8 secs | LR: 0.000259
# INFO:tensorflow:Step 2900 | Loss: 0.2939 | Spent: 2.8 secs | LR: 0.000259
# INFO:tensorflow:Step 2950 | Loss: 0.4128 | Spent: 2.8 secs | LR: 0.000258
# INFO:tensorflow:Step 3000 | Loss: 0.2978 | Spent: 2.7 secs | LR: 0.000257
# INFO:tensorflow:Step 3050 | Loss: 0.4088 | Spent: 2.8 secs | LR: 0.000257
# INFO:tensorflow:Step 3100 | Loss: 0.3347 | Spent: 2.8 secs | LR: 0.000256
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.831
# INFO:tensorflow:Best Accuracy: 0.838
# Reading ./data/train.txt
# INFO:tensorflow:Step 3150 | Loss: 0.2657 | Spent: 30.9 secs | LR: 0.000255
# INFO:tensorflow:Step 3200 | Loss: 0.2702 | Spent: 2.8 secs | LR: 0.000255
# INFO:tensorflow:Step 3250 | Loss: 0.3438 | Spent: 2.7 secs | LR: 0.000254
# INFO:tensorflow:Step 3300 | Loss: 0.3855 | Spent: 2.8 secs | LR: 0.000253
# INFO:tensorflow:Step 3350 | Loss: 0.3658 | Spent: 2.8 secs | LR: 0.000253
# INFO:tensorflow:Step 3400 | Loss: 0.4941 | Spent: 2.8 secs | LR: 0.000252
# INFO:tensorflow:Step 3450 | Loss: 0.3181 | Spent: 2.8 secs | LR: 0.000251
# INFO:tensorflow:Step 3500 | Loss: 0.4357 | Spent: 2.8 secs | LR: 0.000251
# INFO:tensorflow:Step 3550 | Loss: 0.4160 | Spent: 2.8 secs | LR: 0.000250
# INFO:tensorflow:Step 3600 | Loss: 0.1726 | Spent: 2.8 secs | LR: 0.000249
# INFO:tensorflow:Step 3650 | Loss: 0.3849 | Spent: 2.8 secs | LR: 0.000249
# INFO:tensorflow:Step 3700 | Loss: 0.2196 | Spent: 2.8 secs | LR: 0.000248
# INFO:tensorflow:Step 3750 | Loss: 0.2206 | Spent: 2.8 secs | LR: 0.000248
# INFO:tensorflow:Step 3800 | Loss: 0.2396 | Spent: 2.8 secs | LR: 0.000247
# INFO:tensorflow:Step 3850 | Loss: 0.5373 | Spent: 2.8 secs | LR: 0.000246
# INFO:tensorflow:Step 3900 | Loss: 0.3202 | Spent: 2.8 secs | LR: 0.000246
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.857
# INFO:tensorflow:Best Accuracy: 0.857
# Reading ./data/train.txt
# INFO:tensorflow:Step 3950 | Loss: 0.2528 | Spent: 31.0 secs | LR: 0.000245
# INFO:tensorflow:Step 4000 | Loss: 0.3474 | Spent: 2.8 secs | LR: 0.000244
# INFO:tensorflow:Step 4050 | Loss: 0.1393 | Spent: 2.8 secs | LR: 0.000244
# INFO:tensorflow:Step 4100 | Loss: 0.4066 | Spent: 2.7 secs | LR: 0.000243
# INFO:tensorflow:Step 4150 | Loss: 0.3663 | Spent: 2.8 secs | LR: 0.000242
# INFO:tensorflow:Step 4200 | Loss: 0.4062 | Spent: 2.8 secs | LR: 0.000242
# INFO:tensorflow:Step 4250 | Loss: 0.2623 | Spent: 2.8 secs | LR: 0.000241
# INFO:tensorflow:Step 4300 | Loss: 0.3466 | Spent: 2.8 secs | LR: 0.000241
# INFO:tensorflow:Step 4350 | Loss: 0.2855 | Spent: 2.8 secs | LR: 0.000240
# INFO:tensorflow:Step 4400 | Loss: 0.2468 | Spent: 2.8 secs | LR: 0.000239
# INFO:tensorflow:Step 4450 | Loss: 0.2300 | Spent: 2.8 secs | LR: 0.000239
# INFO:tensorflow:Step 4500 | Loss: 0.4564 | Spent: 2.8 secs | LR: 0.000238
# INFO:tensorflow:Step 4550 | Loss: 0.2581 | Spent: 2.8 secs | LR: 0.000238
# INFO:tensorflow:Step 4600 | Loss: 0.1734 | Spent: 2.8 secs | LR: 0.000237
# INFO:tensorflow:Step 4650 | Loss: 0.4532 | Spent: 2.8 secs | LR: 0.000236
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.843
# INFO:tensorflow:Best Accuracy: 0.857
# Reading ./data/train.txt
# INFO:tensorflow:Step 4700 | Loss: 0.4412 | Spent: 31.1 secs | LR: 0.000236
# INFO:tensorflow:Step 4750 | Loss: 0.4024 | Spent: 2.8 secs | LR: 0.000235
# INFO:tensorflow:Step 4800 | Loss: 0.3013 | Spent: 2.8 secs | LR: 0.000235
# INFO:tensorflow:Step 4850 | Loss: 0.3122 | Spent: 2.8 secs | LR: 0.000234
# INFO:tensorflow:Step 4900 | Loss: 0.1981 | Spent: 2.8 secs | LR: 0.000233
# INFO:tensorflow:Step 4950 | Loss: 0.2527 | Spent: 2.8 secs | LR: 0.000233
# INFO:tensorflow:Step 5000 | Loss: 0.3038 | Spent: 2.8 secs | LR: 0.000232
# INFO:tensorflow:Step 5050 | Loss: 0.2579 | Spent: 2.8 secs | LR: 0.000232
# INFO:tensorflow:Step 5100 | Loss: 0.1786 | Spent: 2.8 secs | LR: 0.000231
# INFO:tensorflow:Step 5150 | Loss: 0.2909 | Spent: 2.8 secs | LR: 0.000230
# INFO:tensorflow:Step 5200 | Loss: 0.4053 | Spent: 2.8 secs | LR: 0.000230
# INFO:tensorflow:Step 5250 | Loss: 0.1289 | Spent: 2.8 secs | LR: 0.000229
# INFO:tensorflow:Step 5300 | Loss: 0.2297 | Spent: 2.8 secs | LR: 0.000229
# INFO:tensorflow:Step 5350 | Loss: 0.3065 | Spent: 2.8 secs | LR: 0.000228
# INFO:tensorflow:Step 5400 | Loss: 0.4245 | Spent: 2.7 secs | LR: 0.000227
# INFO:tensorflow:Step 5450 | Loss: 0.3394 | Spent: 2.7 secs | LR: 0.000227
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.856
# INFO:tensorflow:Best Accuracy: 0.857
# Reading ./data/train.txt
# INFO:tensorflow:Step 5500 | Loss: 0.3308 | Spent: 31.5 secs | LR: 0.000226
# INFO:tensorflow:Step 5550 | Loss: 0.4901 | Spent: 2.8 secs | LR: 0.000226
# INFO:tensorflow:Step 5600 | Loss: 0.5263 | Spent: 2.8 secs | LR: 0.000225
# INFO:tensorflow:Step 5650 | Loss: 0.3945 | Spent: 2.8 secs | LR: 0.000225
# INFO:tensorflow:Step 5700 | Loss: 0.1376 | Spent: 2.8 secs | LR: 0.000224
# INFO:tensorflow:Step 5750 | Loss: 0.1354 | Spent: 2.8 secs | LR: 0.000223
# INFO:tensorflow:Step 5800 | Loss: 0.2566 | Spent: 2.8 secs | LR: 0.000223
# INFO:tensorflow:Step 5850 | Loss: 0.2920 | Spent: 2.8 secs | LR: 0.000222
# INFO:tensorflow:Step 5900 | Loss: 0.2506 | Spent: 2.8 secs | LR: 0.000222
# INFO:tensorflow:Step 5950 | Loss: 0.5100 | Spent: 2.8 secs | LR: 0.000221
# INFO:tensorflow:Step 6000 | Loss: 0.5501 | Spent: 2.8 secs | LR: 0.000221
# INFO:tensorflow:Step 6050 | Loss: 0.3577 | Spent: 2.8 secs | LR: 0.000220
# INFO:tensorflow:Step 6100 | Loss: 0.3710 | Spent: 2.8 secs | LR: 0.000219
# INFO:tensorflow:Step 6150 | Loss: 0.4167 | Spent: 2.8 secs | LR: 0.000219
# INFO:tensorflow:Step 6200 | Loss: 0.2323 | Spent: 2.8 secs | LR: 0.000218
# INFO:tensorflow:Step 6250 | Loss: 0.6493 | Spent: 2.8 secs | LR: 0.000218
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.828
# INFO:tensorflow:Best Accuracy: 0.857
# Reading ./data/train.txt
# INFO:tensorflow:Step 6300 | Loss: 0.3677 | Spent: 31.5 secs | LR: 0.000217
# INFO:tensorflow:Step 6350 | Loss: 0.2881 | Spent: 2.8 secs | LR: 0.000217
# INFO:tensorflow:Step 6400 | Loss: 0.3361 | Spent: 2.8 secs | LR: 0.000216
# INFO:tensorflow:Step 6450 | Loss: 0.1913 | Spent: 2.8 secs | LR: 0.000215
# INFO:tensorflow:Step 6500 | Loss: 0.2969 | Spent: 2.8 secs | LR: 0.000215
# INFO:tensorflow:Step 6550 | Loss: 0.3276 | Spent: 2.8 secs | LR: 0.000214
# INFO:tensorflow:Step 6600 | Loss: 0.1792 | Spent: 2.8 secs | LR: 0.000214
# INFO:tensorflow:Step 6650 | Loss: 0.1882 | Spent: 2.8 secs | LR: 0.000213
# INFO:tensorflow:Step 6700 | Loss: 0.2670 | Spent: 2.8 secs | LR: 0.000213
# INFO:tensorflow:Step 6750 | Loss: 0.3149 | Spent: 2.8 secs | LR: 0.000212
# INFO:tensorflow:Step 6800 | Loss: 0.1737 | Spent: 2.8 secs | LR: 0.000212
# INFO:tensorflow:Step 6850 | Loss: 0.6618 | Spent: 2.8 secs | LR: 0.000211
# INFO:tensorflow:Step 6900 | Loss: 0.2844 | Spent: 2.8 secs | LR: 0.000211
# INFO:tensorflow:Step 6950 | Loss: 0.3915 | Spent: 2.8 secs | LR: 0.000210
# INFO:tensorflow:Step 7000 | Loss: 0.2179 | Spent: 2.8 secs | LR: 0.000210
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.867
# INFO:tensorflow:Best Accuracy: 0.867
# Reading ./data/train.txt
# INFO:tensorflow:Step 7050 | Loss: 0.3270 | Spent: 31.2 secs | LR: 0.000209
# INFO:tensorflow:Step 7100 | Loss: 0.5042 | Spent: 2.8 secs | LR: 0.000208
# INFO:tensorflow:Step 7150 | Loss: 0.1503 | Spent: 2.8 secs | LR: 0.000208
# INFO:tensorflow:Step 7200 | Loss: 0.1794 | Spent: 2.7 secs | LR: 0.000207
# INFO:tensorflow:Step 7250 | Loss: 0.2187 | Spent: 2.7 secs | LR: 0.000207
# INFO:tensorflow:Step 7300 | Loss: 0.1840 | Spent: 2.8 secs | LR: 0.000206
# INFO:tensorflow:Step 7350 | Loss: 0.2636 | Spent: 2.8 secs | LR: 0.000206
# INFO:tensorflow:Step 7400 | Loss: 0.2686 | Spent: 2.8 secs | LR: 0.000205
# INFO:tensorflow:Step 7450 | Loss: 0.2904 | Spent: 2.8 secs | LR: 0.000205
# INFO:tensorflow:Step 7500 | Loss: 0.1930 | Spent: 2.8 secs | LR: 0.000204
# INFO:tensorflow:Step 7550 | Loss: 0.3438 | Spent: 2.7 secs | LR: 0.000204
# INFO:tensorflow:Step 7600 | Loss: 0.2936 | Spent: 2.8 secs | LR: 0.000203
# INFO:tensorflow:Step 7650 | Loss: 0.2062 | Spent: 2.8 secs | LR: 0.000203
# INFO:tensorflow:Step 7700 | Loss: 0.3071 | Spent: 2.7 secs | LR: 0.000202
# INFO:tensorflow:Step 7750 | Loss: 0.3298 | Spent: 2.8 secs | LR: 0.000202
# INFO:tensorflow:Step 7800 | Loss: 0.3024 | Spent: 2.8 secs | LR: 0.000201
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.872
# INFO:tensorflow:Best Accuracy: 0.872
# Reading ./data/train.txt
# INFO:tensorflow:Step 7850 | Loss: 0.3207 | Spent: 30.9 secs | LR: 0.000201
# INFO:tensorflow:Step 7900 | Loss: 0.4814 | Spent: 2.7 secs | LR: 0.000200
# INFO:tensorflow:Step 7950 | Loss: 0.2782 | Spent: 2.8 secs | LR: 0.000200
# INFO:tensorflow:Step 8000 | Loss: 0.2698 | Spent: 2.7 secs | LR: 0.000199
# INFO:tensorflow:Step 8050 | Loss: 0.4627 | Spent: 2.7 secs | LR: 0.000199
# INFO:tensorflow:Step 8100 | Loss: 0.2186 | Spent: 2.8 secs | LR: 0.000198
# INFO:tensorflow:Step 8150 | Loss: 0.3284 | Spent: 2.8 secs | LR: 0.000198
# INFO:tensorflow:Step 8200 | Loss: 0.3838 | Spent: 2.8 secs | LR: 0.000197
# INFO:tensorflow:Step 8250 | Loss: 0.3367 | Spent: 2.7 secs | LR: 0.000196
# INFO:tensorflow:Step 8300 | Loss: 0.2122 | Spent: 2.7 secs | LR: 0.000196
# INFO:tensorflow:Step 8350 | Loss: 0.2424 | Spent: 2.8 secs | LR: 0.000195
# INFO:tensorflow:Step 8400 | Loss: 0.1941 | Spent: 2.7 secs | LR: 0.000195
# INFO:tensorflow:Step 8450 | Loss: 0.3314 | Spent: 2.7 secs | LR: 0.000194
# INFO:tensorflow:Step 8500 | Loss: 0.2846 | Spent: 2.8 secs | LR: 0.000194
# INFO:tensorflow:Step 8550 | Loss: 0.2911 | Spent: 2.8 secs | LR: 0.000193
# INFO:tensorflow:Step 8600 | Loss: 0.3898 | Spent: 2.8 secs | LR: 0.000193
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.877
# INFO:tensorflow:Best Accuracy: 0.877
# Reading ./data/train.txt
# INFO:tensorflow:Step 8650 | Loss: 0.3217 | Spent: 31.3 secs | LR: 0.000192
# INFO:tensorflow:Step 8700 | Loss: 0.3134 | Spent: 2.8 secs | LR: 0.000192
# INFO:tensorflow:Step 8750 | Loss: 0.4608 | Spent: 2.7 secs | LR: 0.000192
# INFO:tensorflow:Step 8800 | Loss: 0.1881 | Spent: 2.8 secs | LR: 0.000191
# INFO:tensorflow:Step 8850 | Loss: 0.1783 | Spent: 2.8 secs | LR: 0.000191
# INFO:tensorflow:Step 8900 | Loss: 0.2176 | Spent: 2.8 secs | LR: 0.000190
# INFO:tensorflow:Step 8950 | Loss: 0.0820 | Spent: 2.8 secs | LR: 0.000190
# INFO:tensorflow:Step 9000 | Loss: 0.2375 | Spent: 2.8 secs | LR: 0.000189
# INFO:tensorflow:Step 9050 | Loss: 0.1378 | Spent: 2.8 secs | LR: 0.000189
# INFO:tensorflow:Step 9100 | Loss: 0.1726 | Spent: 2.8 secs | LR: 0.000188
# INFO:tensorflow:Step 9150 | Loss: 0.3642 | Spent: 2.8 secs | LR: 0.000188
# INFO:tensorflow:Step 9200 | Loss: 0.3729 | Spent: 2.8 secs | LR: 0.000187
# INFO:tensorflow:Step 9250 | Loss: 0.2907 | Spent: 2.8 secs | LR: 0.000187
# INFO:tensorflow:Step 9300 | Loss: 0.3174 | Spent: 2.7 secs | LR: 0.000186
# INFO:tensorflow:Step 9350 | Loss: 0.4906 | Spent: 2.8 secs | LR: 0.000186
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.873
# INFO:tensorflow:Best Accuracy: 0.877
# Reading ./data/train.txt
# INFO:tensorflow:Step 9400 | Loss: 0.2310 | Spent: 31.0 secs | LR: 0.000185
# INFO:tensorflow:Step 9450 | Loss: 0.2505 | Spent: 2.8 secs | LR: 0.000185
# INFO:tensorflow:Step 9500 | Loss: 0.3510 | Spent: 2.8 secs | LR: 0.000184
# INFO:tensorflow:Step 9550 | Loss: 0.2389 | Spent: 2.8 secs | LR: 0.000184
# INFO:tensorflow:Step 9600 | Loss: 0.1743 | Spent: 2.7 secs | LR: 0.000183
# INFO:tensorflow:Step 9650 | Loss: 0.1556 | Spent: 2.8 secs | LR: 0.000183
# INFO:tensorflow:Step 9700 | Loss: 0.1534 | Spent: 2.8 secs | LR: 0.000182
# INFO:tensorflow:Step 9750 | Loss: 0.1510 | Spent: 2.8 secs | LR: 0.000182
# INFO:tensorflow:Step 9800 | Loss: 0.2196 | Spent: 2.8 secs | LR: 0.000181
# INFO:tensorflow:Step 9850 | Loss: 0.1390 | Spent: 2.8 secs | LR: 0.000181
# INFO:tensorflow:Step 9900 | Loss: 0.2819 | Spent: 2.7 secs | LR: 0.000181
# INFO:tensorflow:Step 9950 | Loss: 0.3651 | Spent: 2.8 secs | LR: 0.000180
# INFO:tensorflow:Step 10000 | Loss: 0.2958 | Spent: 2.8 secs | LR: 0.000180
# INFO:tensorflow:Step 10050 | Loss: 0.3413 | Spent: 2.8 secs | LR: 0.000179
# INFO:tensorflow:Step 10100 | Loss: 0.3068 | Spent: 2.8 secs | LR: 0.000179
# INFO:tensorflow:Step 10150 | Loss: 0.1741 | Spent: 2.8 secs | LR: 0.000178
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.881
# INFO:tensorflow:Best Accuracy: 0.881
# Reading ./data/train.txt
# INFO:tensorflow:Step 10200 | Loss: 0.1934 | Spent: 30.9 secs | LR: 0.000178
# INFO:tensorflow:Step 10250 | Loss: 0.2215 | Spent: 2.8 secs | LR: 0.000177
# INFO:tensorflow:Step 10300 | Loss: 0.3985 | Spent: 2.8 secs | LR: 0.000177
# INFO:tensorflow:Step 10350 | Loss: 0.1493 | Spent: 2.7 secs | LR: 0.000176
# INFO:tensorflow:Step 10400 | Loss: 0.1563 | Spent: 2.8 secs | LR: 0.000176
# INFO:tensorflow:Step 10450 | Loss: 0.1630 | Spent: 2.7 secs | LR: 0.000176
# INFO:tensorflow:Step 10500 | Loss: 0.2428 | Spent: 2.7 secs | LR: 0.000175
# INFO:tensorflow:Step 10550 | Loss: 0.2300 | Spent: 2.7 secs | LR: 0.000175
# INFO:tensorflow:Step 10600 | Loss: 0.2870 | Spent: 2.7 secs | LR: 0.000174
# INFO:tensorflow:Step 10650 | Loss: 0.1567 | Spent: 2.8 secs | LR: 0.000174
# INFO:tensorflow:Step 10700 | Loss: 0.2512 | Spent: 2.8 secs | LR: 0.000173
# INFO:tensorflow:Step 10750 | Loss: 0.2884 | Spent: 2.8 secs | LR: 0.000173
# INFO:tensorflow:Step 10800 | Loss: 0.1744 | Spent: 2.7 secs | LR: 0.000172
# INFO:tensorflow:Step 10850 | Loss: 0.2871 | Spent: 2.8 secs | LR: 0.000172
# INFO:tensorflow:Step 10900 | Loss: 0.1756 | Spent: 2.7 secs | LR: 0.000172
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.877
# INFO:tensorflow:Best Accuracy: 0.881
# Reading ./data/train.txt
# INFO:tensorflow:Step 10950 | Loss: 0.4244 | Spent: 31.0 secs | LR: 0.000171
# INFO:tensorflow:Step 11000 | Loss: 0.2479 | Spent: 2.7 secs | LR: 0.000171
# INFO:tensorflow:Step 11050 | Loss: 0.2018 | Spent: 2.8 secs | LR: 0.000170
# INFO:tensorflow:Step 11100 | Loss: 0.2970 | Spent: 2.8 secs | LR: 0.000170
# INFO:tensorflow:Step 11150 | Loss: 0.2017 | Spent: 2.8 secs | LR: 0.000169
# INFO:tensorflow:Step 11200 | Loss: 0.3682 | Spent: 2.8 secs | LR: 0.000169
# INFO:tensorflow:Step 11250 | Loss: 0.3479 | Spent: 2.8 secs | LR: 0.000168
# INFO:tensorflow:Step 11300 | Loss: 0.1122 | Spent: 2.8 secs | LR: 0.000168
# INFO:tensorflow:Step 11350 | Loss: 0.3287 | Spent: 2.7 secs | LR: 0.000168
# INFO:tensorflow:Step 11400 | Loss: 0.2680 | Spent: 2.7 secs | LR: 0.000167
# INFO:tensorflow:Step 11450 | Loss: 0.2393 | Spent: 2.8 secs | LR: 0.000167
# INFO:tensorflow:Step 11500 | Loss: 0.3845 | Spent: 2.7 secs | LR: 0.000166
# INFO:tensorflow:Step 11550 | Loss: 0.4039 | Spent: 2.8 secs | LR: 0.000166
# INFO:tensorflow:Step 11600 | Loss: 0.0907 | Spent: 2.8 secs | LR: 0.000165
# INFO:tensorflow:Step 11650 | Loss: 0.1572 | Spent: 2.8 secs | LR: 0.000165
# INFO:tensorflow:Step 11700 | Loss: 0.3890 | Spent: 2.7 secs | LR: 0.000165
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.867
# INFO:tensorflow:Best Accuracy: 0.881
# Reading ./data/train.txt
# INFO:tensorflow:Step 11750 | Loss: 0.1585 | Spent: 31.0 secs | LR: 0.000164
# INFO:tensorflow:Step 11800 | Loss: 0.1991 | Spent: 2.7 secs | LR: 0.000164
# INFO:tensorflow:Step 11850 | Loss: 0.3655 | Spent: 2.7 secs | LR: 0.000163
# INFO:tensorflow:Step 11900 | Loss: 0.3294 | Spent: 2.7 secs | LR: 0.000163
# INFO:tensorflow:Step 11950 | Loss: 0.3369 | Spent: 2.8 secs | LR: 0.000163
# INFO:tensorflow:Step 12000 | Loss: 0.1973 | Spent: 2.8 secs | LR: 0.000162
# INFO:tensorflow:Step 12050 | Loss: 0.2164 | Spent: 2.8 secs | LR: 0.000162
# INFO:tensorflow:Step 12100 | Loss: 0.2099 | Spent: 2.8 secs | LR: 0.000161
# INFO:tensorflow:Step 12150 | Loss: 0.1686 | Spent: 2.8 secs | LR: 0.000161
# INFO:tensorflow:Step 12200 | Loss: 0.3310 | Spent: 2.7 secs | LR: 0.000160
# INFO:tensorflow:Step 12250 | Loss: 0.2390 | Spent: 2.8 secs | LR: 0.000160
# INFO:tensorflow:Step 12300 | Loss: 0.1341 | Spent: 2.8 secs | LR: 0.000160
# INFO:tensorflow:Step 12350 | Loss: 0.2400 | Spent: 2.8 secs | LR: 0.000159
# INFO:tensorflow:Step 12400 | Loss: 0.3144 | Spent: 2.8 secs | LR: 0.000159
# INFO:tensorflow:Step 12450 | Loss: 0.2752 | Spent: 2.8 secs | LR: 0.000158
# INFO:tensorflow:Step 12500 | Loss: 0.2160 | Spent: 2.8 secs | LR: 0.000158
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.881
# INFO:tensorflow:Best Accuracy: 0.881
# Reading ./data/train.txt
# INFO:tensorflow:Step 12550 | Loss: 0.2434 | Spent: 30.9 secs | LR: 0.000158
# INFO:tensorflow:Step 12600 | Loss: 0.2150 | Spent: 2.7 secs | LR: 0.000157
# INFO:tensorflow:Step 12650 | Loss: 0.1658 | Spent: 2.8 secs | LR: 0.000157
# INFO:tensorflow:Step 12700 | Loss: 0.3535 | Spent: 2.8 secs | LR: 0.000156
# INFO:tensorflow:Step 12750 | Loss: 0.2539 | Spent: 2.8 secs | LR: 0.000156
# INFO:tensorflow:Step 12800 | Loss: 0.1459 | Spent: 2.8 secs | LR: 0.000156
# INFO:tensorflow:Step 12850 | Loss: 0.3247 | Spent: 2.8 secs | LR: 0.000155
# INFO:tensorflow:Step 12900 | Loss: 0.2277 | Spent: 2.7 secs | LR: 0.000155
# INFO:tensorflow:Step 12950 | Loss: 0.0992 | Spent: 2.7 secs | LR: 0.000154
# INFO:tensorflow:Step 13000 | Loss: 0.1821 | Spent: 2.8 secs | LR: 0.000154
# INFO:tensorflow:Step 13050 | Loss: 0.2338 | Spent: 2.8 secs | LR: 0.000154
# INFO:tensorflow:Step 13100 | Loss: 0.1217 | Spent: 2.7 secs | LR: 0.000153
# INFO:tensorflow:Step 13150 | Loss: 0.1480 | Spent: 2.7 secs | LR: 0.000153
# INFO:tensorflow:Step 13200 | Loss: 0.2523 | Spent: 2.8 secs | LR: 0.000152
# INFO:tensorflow:Step 13250 | Loss: 0.1656 | Spent: 2.8 secs | LR: 0.000152
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.882
# INFO:tensorflow:Best Accuracy: 0.882
# Reading ./data/train.txt
# INFO:tensorflow:Step 13300 | Loss: 0.1369 | Spent: 30.9 secs | LR: 0.000152
# INFO:tensorflow:Step 13350 | Loss: 0.3370 | Spent: 2.8 secs | LR: 0.000151
# INFO:tensorflow:Step 13400 | Loss: 0.2288 | Spent: 2.8 secs | LR: 0.000151
# INFO:tensorflow:Step 13450 | Loss: 0.3055 | Spent: 2.8 secs | LR: 0.000150
# INFO:tensorflow:Step 13500 | Loss: 0.2827 | Spent: 2.7 secs | LR: 0.000150
# INFO:tensorflow:Step 13550 | Loss: 0.2460 | Spent: 2.8 secs | LR: 0.000150
# INFO:tensorflow:Step 13600 | Loss: 0.0728 | Spent: 2.8 secs | LR: 0.000149
# INFO:tensorflow:Step 13650 | Loss: 0.3786 | Spent: 2.8 secs | LR: 0.000149
# INFO:tensorflow:Step 13700 | Loss: 0.2094 | Spent: 2.8 secs | LR: 0.000149
# INFO:tensorflow:Step 13750 | Loss: 0.1787 | Spent: 2.7 secs | LR: 0.000148
# INFO:tensorflow:Step 13800 | Loss: 0.1146 | Spent: 2.7 secs | LR: 0.000148
# INFO:tensorflow:Step 13850 | Loss: 0.4243 | Spent: 2.8 secs | LR: 0.000147
# INFO:tensorflow:Step 13900 | Loss: 0.1108 | Spent: 2.8 secs | LR: 0.000147
# INFO:tensorflow:Step 13950 | Loss: 0.2956 | Spent: 2.7 secs | LR: 0.000147
# INFO:tensorflow:Step 14000 | Loss: 0.1548 | Spent: 2.7 secs | LR: 0.000146
# INFO:tensorflow:Step 14050 | Loss: 0.2722 | Spent: 2.8 secs | LR: 0.000146
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 14100 | Loss: 0.1988 | Spent: 30.9 secs | LR: 0.000146
# INFO:tensorflow:Step 14150 | Loss: 0.2631 | Spent: 2.7 secs | LR: 0.000145
# INFO:tensorflow:Step 14200 | Loss: 0.0839 | Spent: 2.7 secs | LR: 0.000145
# INFO:tensorflow:Step 14250 | Loss: 0.2355 | Spent: 2.7 secs | LR: 0.000144
# INFO:tensorflow:Step 14300 | Loss: 0.1850 | Spent: 2.8 secs | LR: 0.000144
# INFO:tensorflow:Step 14350 | Loss: 0.1789 | Spent: 2.8 secs | LR: 0.000144
# INFO:tensorflow:Step 14400 | Loss: 0.1715 | Spent: 2.7 secs | LR: 0.000143
# INFO:tensorflow:Step 14450 | Loss: 0.1443 | Spent: 2.8 secs | LR: 0.000143
# INFO:tensorflow:Step 14500 | Loss: 0.2681 | Spent: 2.7 secs | LR: 0.000143
# INFO:tensorflow:Step 14550 | Loss: 0.2704 | Spent: 2.8 secs | LR: 0.000142
# INFO:tensorflow:Step 14600 | Loss: 0.2083 | Spent: 2.8 secs | LR: 0.000142
# INFO:tensorflow:Step 14650 | Loss: 0.2183 | Spent: 2.7 secs | LR: 0.000142
# INFO:tensorflow:Step 14700 | Loss: 0.1445 | Spent: 2.7 secs | LR: 0.000141
# INFO:tensorflow:Step 14750 | Loss: 0.1560 | Spent: 2.7 secs | LR: 0.000141
# INFO:tensorflow:Step 14800 | Loss: 0.3752 | Spent: 2.8 secs | LR: 0.000140
# INFO:tensorflow:Step 14850 | Loss: 0.1455 | Spent: 2.7 secs | LR: 0.000140
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.880
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 14900 | Loss: 0.2096 | Spent: 31.3 secs | LR: 0.000140
# INFO:tensorflow:Step 14950 | Loss: 0.3429 | Spent: 2.8 secs | LR: 0.000139
# INFO:tensorflow:Step 15000 | Loss: 0.3025 | Spent: 2.7 secs | LR: 0.000139
# INFO:tensorflow:Step 15050 | Loss: 0.2306 | Spent: 2.8 secs | LR: 0.000139
# INFO:tensorflow:Step 15100 | Loss: 0.1292 | Spent: 2.8 secs | LR: 0.000138
# INFO:tensorflow:Step 15150 | Loss: 0.1578 | Spent: 2.8 secs | LR: 0.000138
# INFO:tensorflow:Step 15200 | Loss: 0.1129 | Spent: 2.8 secs | LR: 0.000138
# INFO:tensorflow:Step 15250 | Loss: 0.0558 | Spent: 2.7 secs | LR: 0.000137
# INFO:tensorflow:Step 15300 | Loss: 0.2363 | Spent: 2.8 secs | LR: 0.000137
# INFO:tensorflow:Step 15350 | Loss: 0.2646 | Spent: 2.8 secs | LR: 0.000137
# INFO:tensorflow:Step 15400 | Loss: 0.1583 | Spent: 2.8 secs | LR: 0.000136
# INFO:tensorflow:Step 15450 | Loss: 0.2101 | Spent: 2.8 secs | LR: 0.000136
# INFO:tensorflow:Step 15500 | Loss: 0.2821 | Spent: 2.8 secs | LR: 0.000135
# INFO:tensorflow:Step 15550 | Loss: 0.2716 | Spent: 2.8 secs | LR: 0.000135
# INFO:tensorflow:Step 15600 | Loss: 0.2142 | Spent: 2.8 secs | LR: 0.000135
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.877
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 15650 | Loss: 0.2558 | Spent: 30.8 secs | LR: 0.000134
# INFO:tensorflow:Step 15700 | Loss: 0.0755 | Spent: 2.8 secs | LR: 0.000134
# INFO:tensorflow:Step 15750 | Loss: 0.0704 | Spent: 2.8 secs | LR: 0.000134
# INFO:tensorflow:Step 15800 | Loss: 0.1803 | Spent: 2.8 secs | LR: 0.000133
# INFO:tensorflow:Step 15850 | Loss: 0.3169 | Spent: 2.8 secs | LR: 0.000133
# INFO:tensorflow:Step 15900 | Loss: 0.1717 | Spent: 2.8 secs | LR: 0.000133
# INFO:tensorflow:Step 15950 | Loss: 0.1692 | Spent: 2.8 secs | LR: 0.000132
# INFO:tensorflow:Step 16000 | Loss: 0.1386 | Spent: 2.8 secs | LR: 0.000132
# INFO:tensorflow:Step 16050 | Loss: 0.2760 | Spent: 2.8 secs | LR: 0.000132
# INFO:tensorflow:Step 16100 | Loss: 0.2826 | Spent: 2.8 secs | LR: 0.000131
# INFO:tensorflow:Step 16150 | Loss: 0.1244 | Spent: 2.8 secs | LR: 0.000131
# INFO:tensorflow:Step 16200 | Loss: 0.1599 | Spent: 2.8 secs | LR: 0.000131
# INFO:tensorflow:Step 16250 | Loss: 0.1192 | Spent: 2.8 secs | LR: 0.000130
# INFO:tensorflow:Step 16300 | Loss: 0.1256 | Spent: 2.8 secs | LR: 0.000130
# INFO:tensorflow:Step 16350 | Loss: 0.2164 | Spent: 2.8 secs | LR: 0.000130
# INFO:tensorflow:Step 16400 | Loss: 0.2130 | Spent: 2.8 secs | LR: 0.000129
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.884
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 16450 | Loss: 0.2595 | Spent: 31.0 secs | LR: 0.000129
# INFO:tensorflow:Step 16500 | Loss: 0.2890 | Spent: 2.8 secs | LR: 0.000129
# INFO:tensorflow:Step 16550 | Loss: 0.2635 | Spent: 2.7 secs | LR: 0.000128
# INFO:tensorflow:Step 16600 | Loss: 0.1109 | Spent: 2.7 secs | LR: 0.000128
# INFO:tensorflow:Step 16650 | Loss: 0.2549 | Spent: 2.8 secs | LR: 0.000128
# INFO:tensorflow:Step 16700 | Loss: 0.0923 | Spent: 2.8 secs | LR: 0.000127
# INFO:tensorflow:Step 16750 | Loss: 0.0772 | Spent: 2.8 secs | LR: 0.000127
# INFO:tensorflow:Step 16800 | Loss: 0.0811 | Spent: 2.7 secs | LR: 0.000127
# INFO:tensorflow:Step 16850 | Loss: 0.2020 | Spent: 2.8 secs | LR: 0.000126
# INFO:tensorflow:Step 16900 | Loss: 0.2853 | Spent: 2.7 secs | LR: 0.000126
# INFO:tensorflow:Step 16950 | Loss: 0.1422 | Spent: 2.7 secs | LR: 0.000126
# INFO:tensorflow:Step 17000 | Loss: 0.1855 | Spent: 2.7 secs | LR: 0.000125
# INFO:tensorflow:Step 17050 | Loss: 0.2874 | Spent: 2.7 secs | LR: 0.000125
# INFO:tensorflow:Step 17100 | Loss: 0.2193 | Spent: 2.7 secs | LR: 0.000125
# INFO:tensorflow:Step 17150 | Loss: 0.1749 | Spent: 2.7 secs | LR: 0.000124
# INFO:tensorflow:Step 17200 | Loss: 0.1557 | Spent: 2.8 secs | LR: 0.000124
# Reading ./data/test.txt
# INFO:tensorflow:Evaluation: Testing Accuracy: 0.878
# INFO:tensorflow:Best Accuracy: 0.884
# Reading ./data/train.txt
# INFO:tensorflow:Step 17250 | Loss: 0.0716 | Spent: 30.9 secs | LR: 0.000124
# INFO:tensorflow:Step 17300 | Loss: 0.1792 | Spent: 2.8 secs | LR: 0.000124
# INFO:tensorflow:Step 17350 | Loss: 0.0323 | Spent: 2.7 secs | LR: 0.000123
# INFO:tensorflow:Step 17400 | Loss: 0.1377 | Spent: 2.7 secs | LR: 0.000123
# INFO:tensorflow:Step 17450 | Loss: 0.2874 | Spent: 2.7 secs | LR: 0.000123
# INFO:tensorflow:Step 17500 | Loss: 0.2301 | Spent: 2.8 secs | LR: 0.000122
# INFO:tensorflow:Step 17550 | Loss: 0.2631 | Spent: 2.7 secs | LR: 0.000122
# INFO:tensorflow:Step 17600 | Loss: 0.2633 | Spent: 2.8 secs | LR: 0.000122
# INFO:tensorflow:Step 17650 | Loss: 0.0512 | Spent: 2.7 secs | LR: 0.000121
# INFO:tensorflow:Step 17700 | Loss: 0.0522 | Spent: 2.7 secs | LR: 0.000121
# INFO:tensorflow:Step 17750 | Loss: 0.1866 | Spent: 2.8 secs | LR: 0.000121
# INFO:tensorflow:Step 17800 | Loss: 0.1632 | Spent: 2.7 secs | LR: 0.000120
# INFO:tensorflow:Step 17850 | Loss: 0.1579 | Spent: 2.8 secs | LR: 0.000120
# INFO:tensorflow:Step 17900 | Loss: 0.1425 | Spent: 2.7 secs | LR: 0.000120
# INFO:tensorflow:Step 17950 | Loss: 0.2102 | Spent: 2.8 secs | LR: 0.000119
# Reading ./data/test.txt
